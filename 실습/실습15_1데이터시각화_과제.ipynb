# %% [markdown]
# Jupyter Notebook 또는 Interactive Window에서는 %pip install이 더 추천
# !pip install은 셸 명령어  - python interpreter 상태와 별개로 동작 > restart가 필요할 수 있음

# %% [markdown]
# %pip 사용은 python interpreter와 통합되어 동작> restart 필요 없다

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.54.1-cp39-cp39-win_amd64.whl.metadata (167 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.4.0-cp39-cp39-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.2-cp39-cp39-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 7.8/7.8 MB 68.7 MB/s eta 0:00:00
# Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl (211 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.54.1-cp39-cp39-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 121.8 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl (55 kB)
# Downloading pillow-10.4.0-cp39-cp39-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 36.4 MB/s eta 0:00:00
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 importlib-resources-6.4.5 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-10.4.0 pyparsing-3.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# 페이지
import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 25] #x = [0,1,2,3,4]에 대한 값이다 

fig, ax = plt.subplots()
ax.plot(squares, linewidth=3)

# Set chart title and label axes.
ax.set_title("제곱값", fontsize=24)
ax.set_xlabel("값", fontsize=14)
ax.set_ylabel("x의 제곱값", fontsize=14)

# Set size of tick labels.
ax.tick_params(labelsize=14)

plt.show()
# Out:
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44273 (\N{HANGUL SYLLABLE GOB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 경로 설정 (예: 맑은 고딕)
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
# font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"  # Linux의 경우

# 폰트 설정
font_prop = fm.FontProperties(fname=font_path, size=12)
plt.rc('font', family=font_prop.get_name())

# 예제 데이터 시각화
plt.figure(figsize=(8, 6))
plt.plot([1, 2, 3,4,5,6,7,8,9], [1, 4, 9,16,25,36,49,64,81], label='데이터 예시')
plt.title('한글 제목 예시')
plt.xlabel('X축 레이블')
plt.ylabel('Y축 레이블')
plt.legend()
plt.show()

# %%
from matplotlib import font_manager
font_manager.findSystemFonts()
# Out:
# ['C:\\Windows\\Fonts\\msyi.ttf',
#  'C:\\Windows\\Fonts\\DUBAI-REGULAR.TTF',
#  'C:\\Windows\\Fonts\\ebrima.ttf',
#  'C:\\Windows\\Fonts\\cambriaz.ttf',
#  'C:\\Windows\\Fonts\\segoeuib.ttf',
#  'C:\\Windows\\Fonts\\timesbi.ttf',
#  'C:\\Windows\\Fonts\\LFAX.TTF',
#  'C:\\Windows\\Fonts\\webdings.ttf',
#  'C:\\Windows\\Fonts\\cambria.ttc',
#  'C:\\Windows\\Fonts\\CALISTI.TTF',
#  'C:\\Windows\\Fonts\\CENSCBK.TTF',
#  'C:\\Windows\\Fonts\\RAGE.TTF',
#  'C:\\Windows\\Fonts\\msjh.ttc',
#  'C:\\Windows\\Fonts\\segoeuil.ttf',
#  'C:\\Windows\\Fonts\\HARNGTON.TTF',
#  'C:\\Windows\\Fonts\\H2MJSM.TTF',
#  'C:\\Windows\\Fonts\\msjhl.ttc',
#  'C:\\Windows\\Fonts\\impact.ttf',
#  'C:\\Windows\\Fonts\\MP.TTF',
#  'C:\\Windows\\Fonts\\FRAMDCN.TTF',
#  'C:\\Windows\\Fonts\\seguiemj.ttf',
#  'C:\\Windows\\Fonts\\HANDotumExt.ttf',
#  'C:\\Windows\\Fonts\\SCHLBKB.TTF',
#  'C:\\Windows\\Fonts\\pala.ttf',
#  'C:\\Windows\\Fonts\\ROCKEB.TTF',
#  'C:\\Windows\\Fonts\\MSUIGHUR.TTF',
#  'C:\\Windows\\Fonts\\BELL.TTF',
#  'C:\\Windows\\Fonts\\LTYPEB.TTF',
#  'C:\\Windows\\Fonts\\ONYX.TTF',
#  'C:\\Windows\\Fonts\\Inkfree.ttf',
#  'C:\\Windows\\Fonts\\HARLOWSI.TTF',
#  'C:\\Windows\\Fonts\\FRSCRIPT.TTF',
#  'C:\\Windows\\Fonts\\GOTHICB.TTF',
#  'C:\\Windows\\Fonts\\SNAP____.TTF',
#  'C:\\Windows\\Fonts\\LCALLIG.TTF',
#  'C:\\Windows\\Fonts\\segoeuisl.ttf',
#  'C:\\Windows\\Fonts\\HANBatangExtB.ttf',
#  'C:\\Windows\\Fonts\\malgun.ttf',
#  'C:\\Windows\\Fonts\\HTOWERT.TTF',
#  'C:\\Windows\\Fonts\\gadugi.ttf',
#  'C:\\Windows\\Fonts\\segoeuiz.ttf',
#  'C:\\Windows\\Fonts\\BRLNSR.TTF',
#  'C:\\Windows\\Fonts\\JUMJA.TTF',
#  'C:\\Windows\\Fonts\\ARIALN.TTF',
#  'C:\\Windows\\Fonts\\HANBatangB.ttf',
#  'C:\\Windows\\Fonts\\OUTLOOK.TTF',
#  'C:\\Windows\\Fonts\\STENCIL.TTF',
#  'C:\\Windows\\Fonts\\BOD_PSTC.TTF',
#  'C:\\Windows\\Fonts\\OLDENGL.TTF',
#  'C:\\Windows\\Fonts\\constan.ttf',
#  'C:\\Windows\\Fonts\\SCHLBKI.TTF',
#  'C:\\Windows\\Fonts\\MSUIGHUB.TTF',
#  'C:\\Windows\\Fonts\\corbell.ttf',
#  'C:\\Windows\\Fonts\\FRADM.TTF',
#  'C:\\Windows\\Fonts\\ITCBLKAD.TTF',
#  'C:\\Windows\\Fonts\\BOD_BLAI.TTF',
#  'C:\\Windows\\Fonts\\LTYPEO.TTF',
#  'C:\\Windows\\Fonts\\LTYPE.TTF',
#  'C:\\Windows\\Fonts\\PERTILI.TTF',
#  'C:\\Windows\\Fonts\\trebuc.ttf',
#  'C:\\Windows\\Fonts\\calibriz.ttf',
#  'C:\\Windows\\Fonts\\GOTHICI.TTF',
#  'C:\\Windows\\Fonts\\ARIALNBI.TTF',
#  'C:\\Windows\\Fonts\\seguihis.ttf',
#  'C:\\Windows\\Fonts\\GOTHIC.TTF',
#  'C:\\Windows\\Fonts\\HMFMMUEX.TTC',
#  'C:\\Windows\\Fonts\\georgiai.ttf',
#  'C:\\Windows\\Fonts\\MB.TTF',
#  'C:\\Windows\\Fonts\\CENTURY.TTF',
#  'C:\\Windows\\Fonts\\ANTQUAB.TTF',
#  'C:\\Windows\\Fonts\\holomdl2.ttf',
#  'C:\\Windows\\Fonts\\BOD_I.TTF',
#  'C:\\Windows\\Fonts\\BOD_CBI.TTF',
#  'C:\\Windows\\Fonts\\WINGDNG2.TTF',
#  'C:\\Windows\\Fonts\\consolai.ttf',
#  'C:\\Windows\\Fonts\\gulim.ttc',
#  'C:\\Windows\\Fonts\\segoescb.ttf',
#  'C:\\Windows\\Fonts\\GARAIT.TTF',
#  'C:\\Windows\\Fonts\\BOOKOSI.TTF',
#  'C:\\Windows\\Fonts\\CASTELAR.TTF',
#  'C:\\Windows\\Fonts\\mmrtextb.ttf',
#  'C:\\Windows\\Fonts\\courbi.ttf',
#  'C:\\Windows\\Fonts\\YuGothL.ttc',
#  'C:\\Windows\\Fonts\\FREESCPT.TTF',
#  'C:\\Windows\\Fonts\\segoesc.ttf',
#  'C:\\Windows\\Fonts\\BRUSHSCI.TTF',
#  'C:\\Windows\\Fonts\\seguisb.ttf',
#  'C:\\Windows\\Fonts\\H2GTRM.TTF',
#  'C:\\Windows\\Fonts\\BOD_CR.TTF',
#  'C:\\Windows\\Fonts\\verdanai.ttf',
#  'C:\\Windows\\Fonts\\BAUHS93.TTF',
#  'C:\\Windows\\Fonts\\calibrili.ttf',
#  'C:\\Windows\\Fonts\\H2GTRE.TTF',
#  'C:\\Windows\\Fonts\\CALISTB.TTF',
#  'C:\\Windows\\Fonts\\REFSAN.TTF',
#  'C:\\Windows\\Fonts\\TCCB____.TTF',
#  'C:\\Windows\\Fonts\\FRAHV.TTF',
#  'C:\\Windows\\Fonts\\LATINWD.TTF',
#  'C:\\Windows\\Fonts\\couri.ttf',
#  'C:\\Windows\\Fonts\\LFAXI.TTF',
#  'C:\\Windows\\Fonts\\constanb.ttf',
#  'C:\\Windows\\Fonts\\LFAXDI.TTF',
#  'C:\\Windows\\Fonts\\ANTQUAI.TTF',
#  'C:\\Windows\\Fonts\\GOUDOSI.TTF',
#  'C:\\Windows\\Fonts\\HMKMRHD.TTF',
#  'C:\\Windows\\Fonts\\OCRAEXT.TTF',
#  'C:\\Windows\\Fonts\\GARABD.TTF',
#  'C:\\Windows\\Fonts\\SCHLBKBI.TTF',
#  'C:\\Windows\\Fonts\\seguili.ttf',
#  'C:\\Windows\\Fonts\\TCCEB.TTF',
#  'C:\\Windows\\Fonts\\LFAXD.TTF',
#  'C:\\Windows\\Fonts\\ZWAdobeF.TTF',
#  'C:\\Windows\\Fonts\\LeelUIsl.ttf',
#  'C:\\Windows\\Fonts\\mingliub.ttc',
#  'C:\\Windows\\Fonts\\corbelz.ttf',
#  'C:\\Windows\\Fonts\\calibri.ttf',
#  'C:\\Windows\\Fonts\\CALISTBI.TTF',
#  'C:\\Windows\\Fonts\\verdana.ttf',
#  'C:\\Windows\\Fonts\\corbelli.ttf',
#  'C:\\Windows\\Fonts\\MG.TTF',
#  'C:\\Windows\\Fonts\\CALIST.TTF',
#  'C:\\Windows\\Fonts\\BOD_BLAR.TTF',
#  'C:\\Windows\\Fonts\\BKANT.TTF',
#  'C:\\Windows\\Fonts\\mmrtext.ttf',
#  'C:\\Windows\\Fonts\\Candarab.ttf',
#  'C:\\Windows\\Fonts\\comicbd.ttf',
#  'C:\\Windows\\Fonts\\HMKMAMI.TTF',
#  'C:\\Windows\\Fonts\\HANDotumB.ttf',
#  'C:\\Windows\\Fonts\\GOUDOSB.TTF',
#  'C:\\Windows\\Fonts\\corbeli.ttf',
#  'C:\\Windows\\Fonts\\simsunb.ttf',
#  'C:\\Windows\\Fonts\\PER_____.TTF',
#  'C:\\Windows\\Fonts\\RAVIE.TTF',
#  'C:\\Windows\\Fonts\\GLECB.TTF',
#  'C:\\Windows\\Fonts\\GIGI.TTF',
#  'C:\\Windows\\Fonts\\KUNSTLER.TTF',
#  'C:\\Windows\\Fonts\\MTEXTRA.TTF',
#  'C:\\Windows\\Fonts\\FRADMIT.TTF',
#  'C:\\Windows\\Fonts\\ERASDEMI.TTF',
#  'C:\\Windows\\Fonts\\H2MKPB.TTF',
#  'C:\\Windows\\Fonts\\PAPYRUS.TTF',
#  'C:\\Windows\\Fonts\\VIVALDII.TTF',
#  'C:\\Windows\\Fonts\\FRABKIT.TTF',
#  'C:\\Windows\\Fonts\\msgothic.ttc',
#  'C:\\Windows\\Fonts\\monbaiti.ttf',
#  'C:\\Windows\\Fonts\\msyh.ttc',
#  'C:\\Windows\\Fonts\\seguisbi.ttf',
#  'C:\\Windows\\Fonts\\symbol.ttf',
#  'C:\\Windows\\Fonts\\CALIFB.TTF',
#  'C:\\Windows\\Fonts\\MAGNETOB.TTF',
#  'C:\\Windows\\Fonts\\H2GPRM.TTF',
#  'C:\\Windows\\Fonts\\ariali.ttf',
#  'C:\\Windows\\Fonts\\gadugib.ttf',
#  'C:\\Windows\\Fonts\\comici.ttf',
#  'C:\\Windows\\Fonts\\verdanab.ttf',
#  'C:\\Windows\\Fonts\\ENGR.TTF',
#  'C:\\Windows\\Fonts\\ROCC____.TTF',
#  'C:\\Windows\\Fonts\\batang.ttc',
#  'C:\\Windows\\Fonts\\himalaya.ttf',
#  'C:\\Windows\\Fonts\\LeelawUI.ttf',
#  'C:\\Windows\\Fonts\\ntailub.ttf',
#  'C:\\Windows\\Fonts\\PRISTINA.TTF',
#  'C:\\Windows\\Fonts\\bahnschrift.ttf',
#  'C:\\Windows\\Fonts\\BOD_R.TTF',
#  'C:\\Windows\\Fonts\\HTOWERTI.TTF',
#  'C:\\Windows\\Fonts\\INFROMAN.TTF',
#  'C:\\Windows\\Fonts\\ITCEDSCR.TTF',
#  'C:\\Windows\\Fonts\\ROCKBI.TTF',
#  'C:\\Windows\\Fonts\\LBRITED.TTF',
#  'C:\\Windows\\Fonts\\taile.ttf',
#  'C:\\Windows\\Fonts\\COPRGTL.TTF',
#  'C:\\Windows\\Fonts\\cambriai.ttf',
#  'C:\\Windows\\Fonts\\Gabriola.ttf',
#  'C:\\Windows\\Fonts\\YuGothB.ttc',
#  'C:\\Windows\\Fonts\\GLSNECB.TTF',
#  'C:\\Windows\\Fonts\\msyhbd.ttc',
#  'C:\\Windows\\Fonts\\GILI____.TTF',
#  'C:\\Windows\\Fonts\\BRLNSDB.TTF',
#  'C:\\Windows\\Fonts\\javatext.ttf',
#  'C:\\Windows\\Fonts\\BOD_BI.TTF',
#  'C:\\Users\\bhhong\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothic-Regular.ttf',
#  'C:\\Windows\\Fonts\\timesi.ttf',
#  'C:\\Windows\\Fonts\\PLAYBILL.TTF',
#  'C:\\Users\\bhhong\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothic-Bold.ttf',
#  'C:\\Windows\\Fonts\\BOOKOSB.TTF',
#  'C:\\Windows\\Fonts\\H2HDRM.TTF',
#  'C:\\Windows\\Fonts\\trebucbi.ttf',
#  'C:\\Windows\\Fonts\\MT.TTF',
#  'C:\\Windows\\Fonts\\BELLI.TTF',
#  'C:\\Windows\\Fonts\\BOD_B.TTF',
#  'C:\\Windows\\Fonts\\AGENCYR.TTF',
#  'C:\\Windows\\Fonts\\GARA.TTF',
#  'C:\\Windows\\Fonts\\micross.ttf',
#  'C:\\Windows\\Fonts\\GILC____.TTF',
#  'C:\\Windows\\Fonts\\PARCHM.TTF',
#  'C:\\Windows\\Fonts\\CHILLER.TTF',
#  'C:\\Windows\\Fonts\\POORICH.TTF',
#  'C:\\Windows\\Fonts\\tahoma.ttf',
#  'C:\\Windows\\Fonts\\BOOKOSBI.TTF',
#  'C:\\Windows\\Fonts\\corbel.ttf',
#  'C:\\Windows\\Fonts\\ERASBD.TTF',
#  'C:\\Windows\\Fonts\\SCRIPTBL.TTF',
#  'C:\\Windows\\Fonts\\cour.ttf',
#  'C:\\Windows\\Fonts\\arialbd.ttf',
#  'C:\\Windows\\Fonts\\segmdl2.ttf',
#  'C:\\Windows\\Fonts\\SHOWG.TTF',
#  'C:\\Windows\\Fonts\\ROCK.TTF',
#  'C:\\Windows\\Fonts\\Candarali.ttf',
#  'C:\\Windows\\Fonts\\BROADW.TTF',
#  'C:\\Windows\\Fonts\\BOD_CI.TTF',
#  'C:\\Windows\\Fonts\\FELIXTI.TTF',
#  'C:\\Windows\\Fonts\\TCM_____.TTF',
#  'C:\\Windows\\Fonts\\NirmalaB.ttf',
#  'C:\\Windows\\Fonts\\HMFMPYUN.TTF',
#  'C:\\Windows\\Fonts\\MATURASC.TTF',
#  'C:\\Windows\\Fonts\\ERASMD.TTF',
#  'C:\\Windows\\Fonts\\GILBI___.TTF',
#  'C:\\Windows\\Fonts\\GOUDOS.TTF',
#  'C:\\Windows\\Fonts\\calibrib.ttf',
#  'C:\\Windows\\Fonts\\georgiab.ttf',
#  'C:\\Windows\\Fonts\\SitkaZ.ttc',
#  'C:\\Windows\\Fonts\\BRADHITC.TTF',
#  'C:\\Windows\\Fonts\\TCCM____.TTF',
#  'C:\\Windows\\Fonts\\BOD_CB.TTF',
#  'C:\\Windows\\Fonts\\LHANDW.TTF',
#  'C:\\Windows\\Fonts\\LSANSI.TTF',
#  'C:\\Windows\\Fonts\\segoeprb.ttf',
#  'C:\\Windows\\Fonts\\seguibli.ttf',
#  'C:\\Windows\\Fonts\\arial.ttf',
#  'C:\\Windows\\Fonts\\TEMPSITC.TTF',
#  'C:\\Windows\\Fonts\\COOPBL.TTF',
#  'C:\\Windows\\Fonts\\ERASLGHT.TTF',
#  'C:\\Windows\\Fonts\\FORTE.TTF',
#  'C:\\Windows\\Fonts\\seguisli.ttf',
#  'C:\\Windows\\Fonts\\calibril.ttf',
#  'C:\\Windows\\Fonts\\tahomabd.ttf',
#  'C:\\Windows\\Fonts\\FRAHVIT.TTF',
#  'C:\\Windows\\Fonts\\calibrii.ttf',
#  'C:\\Windows\\Fonts\\GIL_____.TTF',
#  'C:\\Windows\\Fonts\\ARIALNB.TTF',
#  'C:\\Users\\bhhong\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothic-ExtraBold.ttf',
#  'C:\\Windows\\Fonts\\PERBI___.TTF',
#  'C:\\Windows\\Fonts\\lucon.ttf',
#  'C:\\Windows\\Fonts\\ITCKRIST.TTF',
#  'C:\\Windows\\Fonts\\DUBAI-MEDIUM.TTF',
#  'C:\\Windows\\Fonts\\GILLUBCD.TTF',
#  'C:\\Windows\\Fonts\\ELEPHNTI.TTF',
#  'C:\\Windows\\Fonts\\VINERITC.TTF',
#  'C:\\Windows\\Fonts\\MH.TTF',
#  'C:\\Windows\\Fonts\\CALIFR.TTF',
#  'C:\\Windows\\Fonts\\BELLB.TTF',
#  'C:\\Windows\\Fonts\\MAIAN.TTF',
#  'C:\\Windows\\Fonts\\LSANSDI.TTF',
#  'C:\\Windows\\Fonts\\constani.ttf',
#  'C:\\Windows\\Fonts\\MTCORSVA.TTF',
#  'C:\\Windows\\Fonts\\times.ttf',
#  'C:\\Windows\\Fonts\\HANBatangExtBB.ttf',
#  'C:\\Windows\\Fonts\\PALSCRI.TTF',
#  'C:\\Windows\\Fonts\\malgunsl.ttf',
#  'C:\\Windows\\Fonts\\LSANSD.TTF',
#  'C:\\Windows\\Fonts\\BRITANIC.TTF',
#  'C:\\Windows\\Fonts\\phagspab.ttf',
#  'C:\\Windows\\Fonts\\MJ.TTF',
#  'C:\\Windows\\Fonts\\GILSANUB.TTF',
#  'C:\\Windows\\Fonts\\BSSYM7.TTF',
#  'C:\\Windows\\Fonts\\segoeuii.ttf',
#  'C:\\Windows\\Fonts\\CENTAUR.TTF',
#  'C:\\Windows\\Fonts\\H2GSRB.TTF',
#  'C:\\Windows\\Fonts\\malgunbd.ttf',
#  'C:\\Windows\\Fonts\\NirmalaS.ttf',
#  'C:\\Windows\\Fonts\\GOTHICBI.TTF',
#  'C:\\Windows\\Fonts\\LEELAWAD.TTF',
#  'C:\\Windows\\Fonts\\wingding.ttf',
#  'C:\\Windows\\Fonts\\CURLZ___.TTF',
#  'C:\\Windows\\Fonts\\IMPRISHA.TTF',
#  'C:\\Windows\\Fonts\\courbd.ttf',
#  'C:\\Windows\\Fonts\\ariblk.ttf',
#  'C:\\Windows\\Fonts\\seguibl.ttf',
#  'C:\\Windows\\Fonts\\LTYPEBO.TTF',
#  'C:\\Windows\\Fonts\\WINGDNG3.TTF',
#  'C:\\Windows\\Fonts\\comic.ttf',
#  'C:\\Windows\\Fonts\\BASKVILL.TTF',
#  'C:\\Windows\\Fonts\\phagspa.ttf',
#  'C:\\Windows\\Fonts\\PERB____.TTF',
#  'C:\\Windows\\Fonts\\FRADMCN.TTF',
#  'C:\\Windows\\Fonts\\HMKMMAG.TTF',
#  'C:\\Windows\\Fonts\\ARIALNI.TTF',
#  'C:\\Windows\\Fonts\\HANBatangExt.ttf',
#  'C:\\Windows\\Fonts\\ebrimabd.ttf',
#  'C:\\Windows\\Fonts\\PERI____.TTF',
#  'C:\\Windows\\Fonts\\georgiaz.ttf',
#  'C:\\Windows\\Fonts\\JOKERMAN.TTF',
#  'C:\\Windows\\Fonts\\Nirmala.ttf',
#  'C:\\Windows\\Fonts\\LSANS.TTF',
#  'C:\\Windows\\Fonts\\segoeui.ttf',
#  'C:\\Windows\\Fonts\\GOUDYSTO.TTF',
#  'C:\\Windows\\Fonts\\YuGothM.ttc',
#  'C:\\Windows\\Fonts\\consolaz.ttf',
#  'C:\\Windows\\Fonts\\AGENCYB.TTF',
#  'C:\\Windows\\Fonts\\Sitka.ttc',
#  'C:\\Windows\\Fonts\\corbelb.ttf',
#  'C:\\Windows\\Fonts\\l_10646.ttf',
#  'C:\\Windows\\Fonts\\HMFMOLD.TTF',
#  'C:\\Windows\\Fonts\\taileb.ttf',
#  'C:\\Windows\\Fonts\\HATTEN.TTF',
#  'C:\\Windows\\Fonts\\seguisym.ttf',
#  'C:\\Windows\\Fonts\\arialbi.ttf',
#  'C:\\Windows\\Fonts\\MISTRAL.TTF',
#  'C:\\Windows\\Fonts\\consola.ttf',
#  'C:\\Windows\\Fonts\\TCB_____.TTF',
#  'C:\\Windows\\Fonts\\BERNHC.TTF',
#  'C:\\Windows\\Fonts\\REFSPCL.TTF',
#  'C:\\Windows\\Fonts\\palab.ttf',
#  'C:\\Windows\\Fonts\\LEELAWDB.TTF',
#  'C:\\Windows\\Fonts\\Candaral.ttf',
#  'C:\\Windows\\Fonts\\PERTIBD.TTF',
#  'C:\\Windows\\Fonts\\HANDotum.ttf',
#  'C:\\Windows\\Fonts\\NIAGENG.TTF',
#  'C:\\Windows\\Fonts\\H2PORM.TTF',
#  'C:\\Windows\\Fonts\\Candaraz.ttf',
#  'C:\\Windows\\Fonts\\trebucit.ttf',
#  'C:\\Windows\\Fonts\\FRABK.TTF',
#  'C:\\Windows\\Fonts\\ROCKI.TTF',
#  'C:\\Windows\\Fonts\\NGULIM.TTF',
#  'C:\\Windows\\Fonts\\MK.TTF',
#  'C:\\Windows\\Fonts\\framdit.ttf',
#  'C:\\Windows\\Fonts\\Candarai.ttf',
#  'C:\\Windows\\Fonts\\ROCCB___.TTF',
#  'C:\\Windows\\Fonts\\H2PORL.TTF',
#  'C:\\Windows\\Fonts\\H2SA1M.TTF',
#  'C:\\Windows\\Fonts\\TCMI____.TTF',
#  'C:\\Windows\\Fonts\\ANTQUABI.TTF',
#  'C:\\Windows\\Fonts\\FTLTLT.TTF',
#  'C:\\Windows\\Fonts\\ROCKB.TTF',
#  'C:\\Windows\\Fonts\\SitkaI.ttc',
#  'C:\\Windows\\Fonts\\ELEPHNT.TTF',
#  'C:\\Windows\\Fonts\\ntailu.ttf',
#  'C:\\Windows\\Fonts\\ALGER.TTF',
#  'C:\\Windows\\Fonts\\BRLNSB.TTF',
#  'C:\\Windows\\Fonts\\verdanaz.ttf',
#  'C:\\Windows\\Fonts\\timesbd.ttf',
#  'C:\\Windows\\Fonts\\MM.TTF',
#  'C:\\Windows\\Fonts\\DUBAI-BOLD.TTF',
#  'C:\\Windows\\Fonts\\SitkaB.ttc',
#  'C:\\Windows\\Fonts\\COLONNA.TTF',
#  'C:\\Windows\\Fonts\\DUBAI-LIGHT.TTF',
#  'C:\\Windows\\Fonts\\ARLRDBD.TTF',
#  'C:\\Windows\\Fonts\\msjhbd.ttc',
#  'C:\\Windows\\Fonts\\palai.ttf',
#  'C:\\Windows\\Fonts\\MOD20.TTF',
#  'C:\\Windows\\Fonts\\palabi.ttf',
#  'C:\\Users\\bhhong\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunGothic.ttf',
#  'C:\\Windows\\Fonts\\LBRITEDI.TTF',
#  'C:\\Windows\\Fonts\\YuGothR.ttc',
#  'C:\\Windows\\Fonts\\GILB____.TTF',
#  'C:\\Windows\\Fonts\\comicz.ttf',
#  'C:\\Windows\\Fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\sylfaen.ttf',
#  'C:\\Windows\\Fonts\\trebucbd.ttf',
#  'C:\\Windows\\Fonts\\segoepr.ttf',
#  'C:\\Windows\\Fonts\\georgia.ttf',
#  'C:\\Windows\\Fonts\\consolab.ttf',
#  'C:\\Windows\\Fonts\\VLADIMIR.TTF',
#  'C:\\Windows\\Fonts\\simsun.ttc',
#  'C:\\Windows\\Fonts\\msyhl.ttc',
#  'C:\\Windows\\Fonts\\H2MJRE.TTF',
#  'C:\\Windows\\Fonts\\constanz.ttf',
#  'C:\\Windows\\Fonts\\LBRITE.TTF',
#  'C:\\Windows\\Fonts\\Candara.ttf',
#  'C:\\Windows\\Fonts\\cambriab.ttf',
#  'C:\\Windows\\Fonts\\HANBatang.ttf',
#  'C:\\Windows\\Fonts\\BOOKOS.TTF',
#  'C:\\Windows\\Fonts\\framd.ttf',
#  'C:\\Windows\\Fonts\\NIAGSOL.TTF',
#  'C:\\Windows\\Fonts\\MN.TTF',
#  'C:\\Windows\\Fonts\\LeelaUIb.ttf',
#  'C:\\Windows\\Fonts\\HYHWPEQ.TTF',
#  'C:\\Windows\\Fonts\\JUICE___.TTF',
#  'C:\\Windows\\Fonts\\CALIFI.TTF',
#  'C:\\Windows\\Fonts\\COPRGTB.TTF',
#  'C:\\Windows\\Fonts\\TCBI____.TTF',
#  'C:\\Windows\\Fonts\\LBRITEI.TTF']

# %%
import matplotlib.pyplot as plt

input_values = [1, 2, 3, 4, 5]
squares = [1, 8, 27, 64, 125] #y = x**3

fig, ax = plt.subplots()
ax.plot(input_values, squares, linewidth=3)

# Set chart title and label axes.
ax.set_title("Square 숫자", fontsize=24)
ax.set_xlabel("x 값", fontsize=14)
ax.set_ylabel("Square 값", fontsize=14)

# Set size of tick labels.
ax.tick_params(labelsize=14)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# x 값의 범위 설정
x = np.linspace(-5, 9, 400)

# 주어진 함수: y = 3(x-2)^2 + 1
y = 3 * (x - 2)**2 + 1 # 2차 함수가 아닌 배열 값을 갖고 있다 

# 도함수: dy/dx = 6(x-2)
dy_dx = 6 * (x - 2)

# 그래프 그리기
plt.figure(figsize=(10, 6))
#help(x) # ndarray이다 > 리스트와 ndarray 차이를 알아야 한다
#print(x[:5])
#print(y[:5])

# 원래 함수의 그래프
plt.plot(x, y, label=r'$y = 3(x-2)^2 + 1$', color='b')

# 도함수의 그래프
plt.plot(x, dy_dx, label=r'$\frac{dy}{dx} = 6(x-2)$', color='r', linestyle='--')

# 그래프의 제목과 축 라벨 설정
plt.title("함수 y = 3(x-2)^2 + 1와 도함수")
plt.xlabel("x 값")
plt.ylabel("y / dy/dx")

# 그리드 추가 및 범례 표시
plt.grid(True)
plt.legend()

# 그래프 보여주기
plt.show()
# Out:
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt

x_values = [1, 2, 3, 5, 6]
y_values = [10, 8, 9, 14, 13]

plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=100)

# Set chart title and label axes.
ax.set_title("산포도", fontsize=24)
ax.set_xlabel("x 값", fontsize=14)
ax.set_ylabel("y 값", fontsize=14)

# Set size of tick labels.
ax.tick_params(labelsize=14)

plt.show()
# Out:
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows 환경에서는 'Malgun Gothic'
## 한글 깨짐 확인 
x_values = [1, 2, 3, 5, 6]
y_values = [10, 8, 9, 14, 13]

plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=100)

# Set chart title and label axes.
ax.set_title('산포도', fontsize=24)
ax.set_xlabel("x 값", fontsize=14)
ax.set_ylabel("y 값", fontsize=14)

# Set size of tick labels.
ax.tick_params(labelsize=14)

plt.show()
# Out:
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 사용 가능한 폰트 리스트 출력 (한글 폰트 확인용)
for font in fm.findSystemFonts(fontpaths=None, fontext='ttf'):
    print(font)

# 폰트 경로를 직접 지정해 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # 맑은 고딕 폰트 경로
font_prop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = font_prop.get_name()
plt.rcParams['axes.unicode_minus'] = False

x_values = [1, 2, 3, 5, 6]
y_values = [10, 8, 9, 14, 13]

fig, ax = plt.subplots() #ax를 사용하여 산포도 그리기 
ax.scatter(x_values, y_values, s=100)

# Set chart title and label axes.
ax.set_title("산포도", fontsize=24)
ax.set_xlabel("x 값", fontsize=14)
ax.set_ylabel("y 값", fontsize=14)

plt.show()
# Out:
# C:\Windows\Fonts\msyi.ttf
# C:\Windows\Fonts\DUBAI-REGULAR.TTF
# C:\Windows\Fonts\ebrima.ttf
# C:\Windows\Fonts\cambriaz.ttf
# C:\Windows\Fonts\segoeuib.ttf
# C:\Windows\Fonts\timesbi.ttf
# C:\Windows\Fonts\LFAX.TTF
# C:\Windows\Fonts\webdings.ttf
# C:\Windows\Fonts\cambria.ttc
# C:\Windows\Fonts\CALISTI.TTF
# C:\Windows\Fonts\CENSCBK.TTF
# C:\Windows\Fonts\RAGE.TTF
# C:\Windows\Fonts\msjh.ttc
# C:\Windows\Fonts\segoeuil.ttf
# C:\Windows\Fonts\HARNGTON.TTF
# C:\Windows\Fonts\H2MJSM.TTF
# C:\Windows\Fonts\msjhl.ttc
# C:\Windows\Fonts\impact.ttf
# C:\Windows\Fonts\MP.TTF
# C:\Windows\Fonts\FRAMDCN.TTF
# C:\Windows\Fonts\seguiemj.ttf
# C:\Windows\Fonts\HANDotumExt.ttf
# C:\Windows\Fonts\SCHLBKB.TTF
# C:\Windows\Fonts\pala.ttf
# C:\Windows\Fonts\ROCKEB.TTF
# C:\Windows\Fonts\MSUIGHUR.TTF
# C:\Windows\Fonts\BELL.TTF
# C:\Windows\Fonts\LTYPEB.TTF
# C:\Windows\Fonts\ONYX.TTF
# C:\Windows\Fonts\Inkfree.ttf
# C:\Windows\Fonts\HARLOWSI.TTF
# C:\Windows\Fonts\FRSCRIPT.TTF
# C:\Windows\Fonts\GOTHICB.TTF
# C:\Windows\Fonts\SNAP____.TTF
# C:\Windows\Fonts\LCALLIG.TTF
# C:\Windows\Fonts\segoeuisl.ttf
# C:\Windows\Fonts\HANBatangExtB.ttf
# C:\Windows\Fonts\malgun.ttf
# C:\Windows\Fonts\HTOWERT.TTF
# C:\Windows\Fonts\gadugi.ttf
# C:\Windows\Fonts\segoeuiz.ttf
# C:\Windows\Fonts\BRLNSR.TTF
# C:\Windows\Fonts\JUMJA.TTF
# C:\Windows\Fonts\ARIALN.TTF
# C:\Windows\Fonts\HANBatangB.ttf
# C:\Windows\Fonts\OUTLOOK.TTF
# C:\Windows\Fonts\STENCIL.TTF
# C:\Windows\Fonts\BOD_PSTC.TTF
# C:\Windows\Fonts\OLDENGL.TTF
# C:\Windows\Fonts\constan.ttf
# C:\Windows\Fonts\SCHLBKI.TTF
# C:\Windows\Fonts\MSUIGHUB.TTF
# C:\Windows\Fonts\corbell.ttf
# C:\Windows\Fonts\FRADM.TTF
# C:\Windows\Fonts\ITCBLKAD.TTF
# C:\Windows\Fonts\BOD_BLAI.TTF
# C:\Windows\Fonts\LTYPEO.TTF
# C:\Windows\Fonts\LTYPE.TTF
# C:\Windows\Fonts\PERTILI.TTF
# C:\Windows\Fonts\trebuc.ttf
# C:\Windows\Fonts\calibriz.ttf
# C:\Windows\Fonts\GOTHICI.TTF
# C:\Windows\Fonts\ARIALNBI.TTF
# C:\Windows\Fonts\seguihis.ttf
# C:\Windows\Fonts\GOTHIC.TTF
# C:\Windows\Fonts\HMFMMUEX.TTC
# C:\Windows\Fonts\georgiai.ttf
# C:\Windows\Fonts\MB.TTF
# C:\Windows\Fonts\CENTURY.TTF
# C:\Windows\Fonts\ANTQUAB.TTF
# C:\Windows\Fonts\holomdl2.ttf
# C:\Windows\Fonts\BOD_I.TTF
# C:\Windows\Fonts\BOD_CBI.TTF
# C:\Windows\Fonts\WINGDNG2.TTF
# C:\Windows\Fonts\consolai.ttf
# C:\Windows\Fonts\gulim.ttc
# C:\Windows\Fonts\segoescb.ttf
# C:\Windows\Fonts\GARAIT.TTF
# C:\Windows\Fonts\BOOKOSI.TTF
# C:\Windows\Fonts\CASTELAR.TTF
# C:\Windows\Fonts\mmrtextb.ttf
# C:\Windows\Fonts\courbi.ttf
# C:\Windows\Fonts\YuGothL.ttc
# C:\Windows\Fonts\FREESCPT.TTF
# C:\Windows\Fonts\segoesc.ttf
# C:\Windows\Fonts\BRUSHSCI.TTF
# C:\Windows\Fonts\seguisb.ttf
# C:\Windows\Fonts\H2GTRM.TTF
# C:\Windows\Fonts\BOD_CR.TTF
# C:\Windows\Fonts\verdanai.ttf
# C:\Windows\Fonts\BAUHS93.TTF
# C:\Windows\Fonts\calibrili.ttf
# C:\Windows\Fonts\H2GTRE.TTF
# C:\Windows\Fonts\CALISTB.TTF
# C:\Windows\Fonts\REFSAN.TTF
# C:\Windows\Fonts\TCCB____.TTF
# C:\Windows\Fonts\FRAHV.TTF
# C:\Windows\Fonts\LATINWD.TTF
# C:\Windows\Fonts\couri.ttf
# C:\Windows\Fonts\LFAXI.TTF
# C:\Windows\Fonts\constanb.ttf
# C:\Windows\Fonts\LFAXDI.TTF
# C:\Windows\Fonts\ANTQUAI.TTF
# C:\Windows\Fonts\GOUDOSI.TTF
# C:\Windows\Fonts\HMKMRHD.TTF
# C:\Windows\Fonts\OCRAEXT.TTF
# C:\Windows\Fonts\GARABD.TTF
# C:\Windows\Fonts\SCHLBKBI.TTF
# C:\Windows\Fonts\seguili.ttf
# C:\Windows\Fonts\TCCEB.TTF
# C:\Windows\Fonts\LFAXD.TTF
# C:\Windows\Fonts\ZWAdobeF.TTF
# C:\Windows\Fonts\LeelUIsl.ttf
# C:\Windows\Fonts\mingliub.ttc
# C:\Windows\Fonts\corbelz.ttf
# C:\Windows\Fonts\calibri.ttf
# C:\Windows\Fonts\CALISTBI.TTF
# C:\Windows\Fonts\verdana.ttf
# C:\Windows\Fonts\corbelli.ttf
# C:\Windows\Fonts\MG.TTF
# C:\Windows\Fonts\CALIST.TTF
# C:\Windows\Fonts\BOD_BLAR.TTF
# C:\Windows\Fonts\BKANT.TTF
# C:\Windows\Fonts\mmrtext.ttf
# C:\Windows\Fonts\Candarab.ttf
# C:\Windows\Fonts\comicbd.ttf
# C:\Windows\Fonts\HMKMAMI.TTF
# C:\Windows\Fonts\HANDotumB.ttf
# C:\Windows\Fonts\GOUDOSB.TTF
# C:\Windows\Fonts\corbeli.ttf
# C:\Windows\Fonts\simsunb.ttf
# C:\Windows\Fonts\PER_____.TTF
# C:\Windows\Fonts\RAVIE.TTF
# C:\Windows\Fonts\GLECB.TTF
# C:\Windows\Fonts\GIGI.TTF
# C:\Windows\Fonts\KUNSTLER.TTF
# C:\Windows\Fonts\MTEXTRA.TTF
# C:\Windows\Fonts\FRADMIT.TTF
# C:\Windows\Fonts\ERASDEMI.TTF
# C:\Windows\Fonts\H2MKPB.TTF
# C:\Windows\Fonts\PAPYRUS.TTF
# C:\Windows\Fonts\VIVALDII.TTF
# C:\Windows\Fonts\FRABKIT.TTF
# C:\Windows\Fonts\msgothic.ttc
# C:\Windows\Fonts\monbaiti.ttf
# C:\Windows\Fonts\msyh.ttc
# C:\Windows\Fonts\seguisbi.ttf
# C:\Windows\Fonts\symbol.ttf
# C:\Windows\Fonts\CALIFB.TTF
# C:\Windows\Fonts\MAGNETOB.TTF
# C:\Windows\Fonts\H2GPRM.TTF
# C:\Windows\Fonts\ariali.ttf
# C:\Windows\Fonts\gadugib.ttf
# C:\Windows\Fonts\comici.ttf
# C:\Windows\Fonts\verdanab.ttf
# C:\Windows\Fonts\ENGR.TTF
# C:\Windows\Fonts\ROCC____.TTF
# C:\Windows\Fonts\batang.ttc
# C:\Windows\Fonts\himalaya.ttf
# C:\Windows\Fonts\LeelawUI.ttf
# C:\Windows\Fonts\ntailub.ttf
# C:\Windows\Fonts\PRISTINA.TTF
# C:\Windows\Fonts\bahnschrift.ttf
# C:\Windows\Fonts\BOD_R.TTF
# C:\Windows\Fonts\HTOWERTI.TTF
# C:\Windows\Fonts\INFROMAN.TTF
# C:\Windows\Fonts\ITCEDSCR.TTF
# C:\Windows\Fonts\ROCKBI.TTF
# C:\Windows\Fonts\LBRITED.TTF
# C:\Windows\Fonts\taile.ttf
# C:\Windows\Fonts\COPRGTL.TTF
# C:\Windows\Fonts\cambriai.ttf
# C:\Windows\Fonts\Gabriola.ttf
# C:\Windows\Fonts\YuGothB.ttc
# C:\Windows\Fonts\GLSNECB.TTF
# C:\Windows\Fonts\msyhbd.ttc
# C:\Windows\Fonts\GILI____.TTF
# C:\Windows\Fonts\BRLNSDB.TTF
# C:\Windows\Fonts\javatext.ttf
# C:\Windows\Fonts\BOD_BI.TTF
# C:\Users\bhhong\AppData\Local\Microsoft\Windows\Fonts\NanumGothic-Regular.ttf
# C:\Windows\Fonts\timesi.ttf
# C:\Windows\Fonts\PLAYBILL.TTF
# C:\Users\bhhong\AppData\Local\Microsoft\Windows\Fonts\NanumGothic-Bold.ttf
# C:\Windows\Fonts\BOOKOSB.TTF
# C:\Windows\Fonts\H2HDRM.TTF
# C:\Windows\Fonts\trebucbi.ttf
# C:\Windows\Fonts\MT.TTF
# C:\Windows\Fonts\BELLI.TTF
# C:\Windows\Fonts\BOD_B.TTF
# C:\Windows\Fonts\AGENCYR.TTF
# C:\Windows\Fonts\GARA.TTF
# C:\Windows\Fonts\micross.ttf
# C:\Windows\Fonts\GILC____.TTF
# C:\Windows\Fonts\PARCHM.TTF
# C:\Windows\Fonts\CHILLER.TTF
# C:\Windows\Fonts\POORICH.TTF
# C:\Windows\Fonts\tahoma.ttf
# C:\Windows\Fonts\BOOKOSBI.TTF
# C:\Windows\Fonts\corbel.ttf
# C:\Windows\Fonts\ERASBD.TTF
# C:\Windows\Fonts\SCRIPTBL.TTF
# C:\Windows\Fonts\cour.ttf
# C:\Windows\Fonts\arialbd.ttf
# C:\Windows\Fonts\segmdl2.ttf
# C:\Windows\Fonts\SHOWG.TTF
# C:\Windows\Fonts\ROCK.TTF
# C:\Windows\Fonts\Candarali.ttf
# C:\Windows\Fonts\BROADW.TTF
# C:\Windows\Fonts\BOD_CI.TTF
# C:\Windows\Fonts\FELIXTI.TTF
# C:\Windows\Fonts\TCM_____.TTF
# C:\Windows\Fonts\NirmalaB.ttf
# C:\Windows\Fonts\HMFMPYUN.TTF
# C:\Windows\Fonts\MATURASC.TTF
# C:\Windows\Fonts\ERASMD.TTF
# C:\Windows\Fonts\GILBI___.TTF
# C:\Windows\Fonts\GOUDOS.TTF
# C:\Windows\Fonts\calibrib.ttf
# C:\Windows\Fonts\georgiab.ttf
# C:\Windows\Fonts\SitkaZ.ttc
# C:\Windows\Fonts\BRADHITC.TTF
# C:\Windows\Fonts\TCCM____.TTF
# C:\Windows\Fonts\BOD_CB.TTF
# C:\Windows\Fonts\LHANDW.TTF
# C:\Windows\Fonts\LSANSI.TTF
# C:\Windows\Fonts\segoeprb.ttf
# C:\Windows\Fonts\seguibli.ttf
# C:\Windows\Fonts\arial.ttf
# C:\Windows\Fonts\TEMPSITC.TTF
# C:\Windows\Fonts\COOPBL.TTF
# C:\Windows\Fonts\ERASLGHT.TTF
# C:\Windows\Fonts\FORTE.TTF
# C:\Windows\Fonts\seguisli.ttf
# C:\Windows\Fonts\calibril.ttf
# C:\Windows\Fonts\tahomabd.ttf
# C:\Windows\Fonts\FRAHVIT.TTF
# C:\Windows\Fonts\calibrii.ttf
# C:\Windows\Fonts\GIL_____.TTF
# C:\Windows\Fonts\ARIALNB.TTF
# C:\Users\bhhong\AppData\Local\Microsoft\Windows\Fonts\NanumGothic-ExtraBold.ttf
# C:\Windows\Fonts\PERBI___.TTF
# C:\Windows\Fonts\lucon.ttf
# C:\Windows\Fonts\ITCKRIST.TTF
# C:\Windows\Fonts\DUBAI-MEDIUM.TTF
# C:\Windows\Fonts\GILLUBCD.TTF
# C:\Windows\Fonts\ELEPHNTI.TTF
# C:\Windows\Fonts\VINERITC.TTF
# C:\Windows\Fonts\MH.TTF
# C:\Windows\Fonts\CALIFR.TTF
# C:\Windows\Fonts\BELLB.TTF
# C:\Windows\Fonts\MAIAN.TTF
# C:\Windows\Fonts\LSANSDI.TTF
# C:\Windows\Fonts\constani.ttf
# C:\Windows\Fonts\MTCORSVA.TTF
# C:\Windows\Fonts\times.ttf
# C:\Windows\Fonts\HANBatangExtBB.ttf
# C:\Windows\Fonts\PALSCRI.TTF
# C:\Windows\Fonts\malgunsl.ttf
# C:\Windows\Fonts\LSANSD.TTF
# C:\Windows\Fonts\BRITANIC.TTF
# C:\Windows\Fonts\phagspab.ttf
# C:\Windows\Fonts\MJ.TTF
# C:\Windows\Fonts\GILSANUB.TTF
# C:\Windows\Fonts\BSSYM7.TTF
# C:\Windows\Fonts\segoeuii.ttf
# C:\Windows\Fonts\CENTAUR.TTF
# C:\Windows\Fonts\H2GSRB.TTF
# C:\Windows\Fonts\malgunbd.ttf
# C:\Windows\Fonts\NirmalaS.ttf
# C:\Windows\Fonts\GOTHICBI.TTF
# C:\Windows\Fonts\LEELAWAD.TTF
# C:\Windows\Fonts\wingding.ttf
# C:\Windows\Fonts\CURLZ___.TTF
# C:\Windows\Fonts\IMPRISHA.TTF
# C:\Windows\Fonts\courbd.ttf
# C:\Windows\Fonts\ariblk.ttf
# C:\Windows\Fonts\seguibl.ttf
# C:\Windows\Fonts\LTYPEBO.TTF
# C:\Windows\Fonts\WINGDNG3.TTF
# C:\Windows\Fonts\comic.ttf
# C:\Windows\Fonts\BASKVILL.TTF
# C:\Windows\Fonts\phagspa.ttf
# C:\Windows\Fonts\PERB____.TTF
# C:\Windows\Fonts\FRADMCN.TTF
# C:\Windows\Fonts\HMKMMAG.TTF
# C:\Windows\Fonts\ARIALNI.TTF
# C:\Windows\Fonts\HANBatangExt.ttf
# C:\Windows\Fonts\ebrimabd.ttf
# C:\Windows\Fonts\PERI____.TTF
# C:\Windows\Fonts\georgiaz.ttf
# C:\Windows\Fonts\JOKERMAN.TTF
# C:\Windows\Fonts\Nirmala.ttf
# C:\Windows\Fonts\LSANS.TTF
# C:\Windows\Fonts\segoeui.ttf
# C:\Windows\Fonts\GOUDYSTO.TTF
# C:\Windows\Fonts\YuGothM.ttc
# C:\Windows\Fonts\consolaz.ttf
# C:\Windows\Fonts\AGENCYB.TTF
# C:\Windows\Fonts\Sitka.ttc
# C:\Windows\Fonts\corbelb.ttf
# C:\Windows\Fonts\l_10646.ttf
# C:\Windows\Fonts\HMFMOLD.TTF
# C:\Windows\Fonts\taileb.ttf
# C:\Windows\Fonts\HATTEN.TTF
# C:\Windows\Fonts\seguisym.ttf
# C:\Windows\Fonts\arialbi.ttf
# C:\Windows\Fonts\MISTRAL.TTF
# C:\Windows\Fonts\consola.ttf
# C:\Windows\Fonts\TCB_____.TTF
# C:\Windows\Fonts\BERNHC.TTF
# C:\Windows\Fonts\REFSPCL.TTF
# C:\Windows\Fonts\palab.ttf
# C:\Windows\Fonts\LEELAWDB.TTF
# C:\Windows\Fonts\Candaral.ttf
# C:\Windows\Fonts\PERTIBD.TTF
# C:\Windows\Fonts\HANDotum.ttf
# C:\Windows\Fonts\NIAGENG.TTF
# C:\Windows\Fonts\H2PORM.TTF
# C:\Windows\Fonts\Candaraz.ttf
# C:\Windows\Fonts\trebucit.ttf
# C:\Windows\Fonts\FRABK.TTF
# C:\Windows\Fonts\ROCKI.TTF
# C:\Windows\Fonts\NGULIM.TTF
# C:\Windows\Fonts\MK.TTF
# C:\Windows\Fonts\framdit.ttf
# C:\Windows\Fonts\Candarai.ttf
# C:\Windows\Fonts\ROCCB___.TTF
# C:\Windows\Fonts\H2PORL.TTF
# C:\Windows\Fonts\H2SA1M.TTF
# C:\Windows\Fonts\TCMI____.TTF
# C:\Windows\Fonts\ANTQUABI.TTF
# C:\Windows\Fonts\FTLTLT.TTF
# C:\Windows\Fonts\ROCKB.TTF
# C:\Windows\Fonts\SitkaI.ttc
# C:\Windows\Fonts\ELEPHNT.TTF
# C:\Windows\Fonts\ntailu.ttf
# C:\Windows\Fonts\ALGER.TTF
# C:\Windows\Fonts\BRLNSB.TTF
# C:\Windows\Fonts\verdanaz.ttf
# C:\Windows\Fonts\timesbd.ttf
# C:\Windows\Fonts\MM.TTF
# C:\Windows\Fonts\DUBAI-BOLD.TTF
# C:\Windows\Fonts\SitkaB.ttc
# C:\Windows\Fonts\COLONNA.TTF
# C:\Windows\Fonts\DUBAI-LIGHT.TTF
# C:\Windows\Fonts\ARLRDBD.TTF
# C:\Windows\Fonts\msjhbd.ttc
# C:\Windows\Fonts\palai.ttf
# C:\Windows\Fonts\MOD20.TTF
# C:\Windows\Fonts\palabi.ttf
# C:\Users\bhhong\AppData\Local\Microsoft\Windows\Fonts\NanumBarunGothic.ttf
# C:\Windows\Fonts\LBRITEDI.TTF
# C:\Windows\Fonts\YuGothR.ttc
# C:\Windows\Fonts\GILB____.TTF
# C:\Windows\Fonts\comicz.ttf
# C:\Windows\Fonts\mvboli.ttf
# C:\Windows\Fonts\sylfaen.ttf
# C:\Windows\Fonts\trebucbd.ttf
# C:\Windows\Fonts\segoepr.ttf
# C:\Windows\Fonts\georgia.ttf
# C:\Windows\Fonts\consolab.ttf
# C:\Windows\Fonts\VLADIMIR.TTF
# C:\Windows\Fonts\simsun.ttc
# C:\Windows\Fonts\msyhl.ttc
# C:\Windows\Fonts\H2MJRE.TTF
# C:\Windows\Fonts\constanz.ttf
# C:\Windows\Fonts\LBRITE.TTF
# C:\Windows\Fonts\Candara.ttf
# C:\Windows\Fonts\cambriab.ttf
# C:\Windows\Fonts\HANBatang.ttf
# C:\Windows\Fonts\BOOKOS.TTF
# C:\Windows\Fonts\framd.ttf
# C:\Windows\Fonts\NIAGSOL.TTF
# C:\Windows\Fonts\MN.TTF
# C:\Windows\Fonts\LeelaUIb.ttf
# C:\Windows\Fonts\HYHWPEQ.TTF
# C:\Windows\Fonts\JUICE___.TTF
# C:\Windows\Fonts\CALIFI.TTF
# C:\Windows\Fonts\COPRGTB.TTF
# C:\Windows\Fonts\TCBI____.TTF
# C:\Windows\Fonts\LBRITEI.TTF

# %% [markdown]
# 넘파이 맛보기

# %%
import numpy as np
import matplotlib.pyplot as plt
############### 
### plt.title('군집 산포도') 출력을 위한 한글 폰트 설정
# 한글 폰트 경로 설정 (예: 맑은 고딕)
#font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
# 폰트 설정
#font_prop = fm.FontProperties(fname=font_path, size=12)
#plt.rc('font', family=font_prop.get_name())
#############

# 임의의 군집(클러스터) 데이터를 생성하는 함수 => 이 함수를 이해하는 것이 중요
def generate_cluster(center, num_points, spread):
    # 정규 분포를 따르는 점들을 생성
    points = np.random.randn(num_points, 2) * spread + center # 난수를 num_points 갯수 만큼, 2차원으로 생성
    return points
# np.random.randn(d0, d1, ..., dn)은 주어진 차원(d0, d1, ..., dn)의 배열을 생성
# num_points: 배열의 첫 번째 차원의 크기, 즉 생성할 데이터 포인트의 개수
# 2: 배열의 두 번째 차원의 크기, 즉 각 데이터 포인트의 차원

# 각 군집의 중심, 점 개수, 확산 정도 설정
cluster_1 = generate_cluster(center=[2, 3], num_points=100, spread=0.9)
cluster_2 = generate_cluster(center=[7, 8], num_points=200, spread=0.8)
cluster_3 = generate_cluster(center=[5, 2], num_points=300, spread=0.99)

print(cluster_1[:5])

# 각 군집을 하나의 배열로 합침
all_points = np.vstack((cluster_1, cluster_2, cluster_3))
# NumPy의 vstack 함수를 사용하여 여러 배열을 수직으로 쌓아 새로운 배열을 생성하는 함수
# 군집을 시각화
plt.figure(figsize=(8, 6))

# 첫 번째 군집을 파란색으로
plt.scatter(cluster_1[:, 0], cluster_1[:, 1], color='blue', label='Cluster 1', alpha=0.6)

# 두 번째 군집을 빨간색으로
plt.scatter(cluster_2[:, 0], cluster_2[:, 1], color='red', label='Cluster 2', alpha=0.6)

# 세 번째 군집을 녹색으로
plt.scatter(cluster_3[:, 0], cluster_3[:, 1], color='green', label='Cluster 3', alpha=0.6)

# 그래프 설정
plt.title('군집 산포도')
plt.xlabel('X-축')
plt.ylabel('Y-축')
plt.legend()
plt.grid(True)

# 그래프 출력
plt.show()
# Out:
# [[0.62985064 4.04948692]
#  [4.10143063 3.26885194]
#  [3.20062777 3.94870939]
#  [3.19164866 2.81245724]
#  [0.46205176 5.48938908]]

# %%
from random import choice


class RandomWalk:
    """A class to generate random walks."""

    def __init__(self, num_points=5000):
        """Initialize attributes of a walk."""
        self.num_points = num_points

        # All walks start at (0, 0).
        self.x_values = [0]
        self.y_values = [0]

    def fill_walk(self):
        """Calculate all the points in the walk."""
        # Keep taking steps until the walk reaches the desired length.
        while len(self.x_values) < self.num_points:
            ###################
            ### 동서남북 대각선 8가지 방향으로 이동하는 코드 작성
            # 이동 방향을 정의
            directions = [
                (1, 0),    # 동쪽
                (-1, 0),   # 서쪽
                (0, 1),    # 북쪽
                (0, -1),   # 남쪽
                (1, 1),    # 북동쪽
                (-1, 1),   # 북서쪽
                (1, -1),   # 남동쪽
                (-1, -1)   # 남서쪽
            ]

            ### 코딩할 부분
            ###############################

            # Decide which direction to go, and how far to go.
            #x_direction = choice([1, -1])
            #x_distance = choice([0, 1, 2, 3, 4])
            #x_step = x_direction * x_distance

            #y_direction = choice([1, -1])
            #y_distance = choice([0, 1, 2, 3, 4])
            #y_step = y_direction * y_distance

            # Reject moves that go nowhere.
            if x_step == 0 and y_step == 0:
                continue

            # Calculate the new position.
            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step

            self.x_values.append(x)
            self.y_values.append(y)

# %%
import matplotlib.pyplot as plt

#from random_walk import RandomWalk

# Keep making new walks, as long as the program is active.
while True:
    # Make a random walk.
    rw = RandomWalk(10000)
    rw.fill_walk()

    # Plot the points in the walk.
    plt.style.use('classic')
    fig, ax = plt.subplots()
    point_numbers = range(rw.num_points)
    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues,
       edgecolors='none', s=10)
    ax.set_aspect('equal')

    # Emphasize the first and last points.
    ax.scatter(0, 0, c='green', edgecolors='none', s=100)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolors='none',
        s=100)

    # Remove the axes.
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(True)
    
    plt.show()

    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break

# %%
### 벌레 이동 코딩 문제 구현 >> 
### 체스에 0이 없어질 때까지 이동 >> 바둑판 19 x19 으로 수정하는 코딩 
import numpy as np
import random
import matplotlib.pyplot as plt

# 10x10 배열 생성 (초기 값은 모두 0)
grid = np.zeros((8, 8), dtype=int)

# 벌레의 초기 위치 (임의로 설정)
x, y = random.randint(0, 7), random.randint(0, 7)

# 벌레의 이동 방향 (동서남북 및 대각선 8방향)
directions = [
    (-1, 0), (1, 0),  # 남, 북
    (0, -1), (0, 1),  # 서, 동
    (-1, -1), (-1, 1),  # 북서, 북동
    (1, -1), (1, 1)  # 남서, 남동
]

# 반복 실행
steps = 0
while np.any(grid == 0):
    # 현재 위치에 1 추가
#### 구현할 코드

# 결과 출력
print(f"총 {steps} 번 이동 후 배열이 채워졌습니다.")

# 배열의 결과를 시각화 (그래프 출력)
plt.imshow(grid, cmap='viridis', interpolation='none')
plt.colorbar(label="방문횟수")
plt.title("벌레의 이동 경로: 바둑판  10x10 Grid")
plt.show()
# Out:
# 총 304 번 이동 후 배열이 채워졌습니다.
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48268 (\N{HANGUL SYLLABLE BEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48148 (\N{HANGUL SYLLABLE BA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46161 (\N{HANGUL SYLLABLE DUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48169 (\N{HANGUL SYLLABLE BANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54943 (\N{HANGUL SYLLABLE HOES}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bhhong\anaconda3\envs\py3_12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# pip install --user plotly

# %%
import sys
print(sys.prefix)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python39

# %% [markdown]
# conda install pandas:
#
# Anaconda 또는 Miniconda에서 사용하는 패키지 관리 시스템인 Conda를 통해 패키지를 설치: Conda는 pandas를 설치할 때, pandas와 호환되는 다른 패키지(예: numpy, scipy, matplotlib 등)를 자동으로 설치하거나, 호환성을 엄격하게 관리하여 최적화된 버전을 설치
#
# pip install pandas:
#
# Python의 기본 패키지 관리 시스템인 pip를 사용하여 패키지를 설치:pip는 주로 Python 패키지만을 다루며, 설치된 패키지의 의존성을 해결하지만 conda만큼 광범위한 관리 기능은 없다

# %%
import random

# Die 클래스를 정의 (6면체 주사위)  
class Die:
    def __init__(self):
        self.num_sides = 6  # 주사위 면의 수

    # 주사위를 던지는 함수 (1-6 사이 임의 값을 반환)
    def roll(self):
        return random.randint(1, self.num_sides)

# %%
import plotly.express as px

# Create a D6.
die = Die() #Dice는 주사위 복수개 

# Make some rolls, and store results in a list.
results = []
for roll_num in range(1000):
    result = die.roll()
    results.append(result)

# Analyze the results.
frequencies = []
poss_results = range(1, die.num_sides+1)
for value in poss_results:
    frequency = results.count(value)
    frequencies.append(frequency)

# Visualize the results.
title = "주사위 1,000회 결과"
labels = {'x': '주사위값', 'y': '빈도수'}
fig = px.bar(x=poss_results, y=frequencies, title=title, labels=labels)
fig.show()

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#######################
# 한글 폰트 경로 설정 (예: 맑은 고딕)
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우

# 폰트 설정
font_prop = fm.FontProperties(fname=font_path, size=12)
plt.rc('font', family=font_prop.get_name())
#######################

# 주사위 3개를 100번 던져서 합을 구하는 함수
def roll_dice(num_trials):
    die1 = Die()
    die2 = Die()
    die3 = Die()
    
    results = []
    for _ in range(num_trials):
        total = die1.roll() + die2.roll() + die3.roll()
        results.append(total)
    
    return results

# 100번 시행
num_trials = 100
results = roll_dice(num_trials)

# 결과의 빈도 계산
poss_results = range(3, 19)  # 가능한 주사위의 합 값 (3~18)
frequencies = [results.count(x) for x in poss_results]  # 각 합의 빈도 계산

# 막대 그래프 시각화
plt.bar(poss_results, frequencies, color='blue', alpha=0.7)
plt.title(f"3개 주사위 값의 합을 {num_trials}번 반복한 막대차트")
plt.xlabel("3개 주사위 값의 합")
plt.ylabel("빈도수")
plt.xticks(poss_results)  # x축의 값 설정

# 그래프 보여주기
plt.grid(axis='y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5 font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
#       7 # 폰트 설정
# ----> 8 font_prop = fm.FontProperties(fname=font_path, size=12)
#       9 plt.rc('font', family=font_prop.get_name())
#      10 #######################
#      11
#      12 # 주사위 3개를 100번 던져서 합을 구하는 함수
#
# NameError: name 'fm' is not defined

# %% [markdown]
# 로또 복권 파이썬 코딩하기

# %%
# Lotto 복권 코딩
## 1 ~ 45 숫자를 중복없이 6개 뽑고, 보너스 번호를 중복없이 1개를 뽑는다
### 1등: 6개 숫자, 2등: 5개 숫자 + 보너스, 3등: 5개 숫자, 4등: 4개, 5등: 3개 
import random

# 복권 시스템 클래스
class LottoSystem:
    def __init__(self, num_tickets=10):
        self.num_tickets = num_tickets
        self.tickets = []   #10000장의 복권 발행
        self.winning_numbers = set()   #당첨 복권 1개 추첨
        self.results = {
            "1등": [],
            "2등": [],
            "3등": [],
            "4등": [],   #당첨 복권이 append
            "5등": []
        }

    #복권 발행
    def generate_lotto_tickets(self):
        for tickets in range(1000):
            tickets = [set(random.randint(1,45) for i in range(7))]
            self.tickets.append(tickets)
        
            
        # for문 사용 :   10000개의 복권 만들어야함
            # 난수 생성 - 7개 생성
            # self.tickets.append(생성된 티켓을 넣음)

    # 당첨 복권
    def draw_winning_numbers(self):
     self.winning_numbers = set(random.randint(1,45) for i in range(6))
        #당첨 복권 - 6개 난수 생성 저장
        # self.winning_numbers = 티켓을 넣어줌
        
    # 당첨 처리 
    def check_winners(self):
      for ticket in self.tickets:
       self.check_ti
         
        #10000장의 복권에 대하여 check_ticket() 호출하여 당첨인지 아닌지를 돌림
        # for ticket in self.tickets:
            # self.check_ticket(ticket)
        #1등 당첨 확률
        ##전체 복권의 당첨 확률 계산 => 0.03% 내외

    # 당첨 분류
       def check_ticket(self, ticket):   #매개변수 ticket으로 전달된 복권 당첨 여부 체크
        #ticket은 10000장 중의 하나 <-> winning_numbers와 비교
        ##set()으로 만듬 result = set1 & set2를 비교
        matched_count = len(result)

        if matched_count == 6:
            self.results["1등"].append(ticket)
        elif matched_count == 5 and bonus_matched:
            self.results["2등"].append(ticket)
        elif matched_count == 5:
            self.results["3등"].append(ticket)
        elif matched_count == 4:
            self.results["4등"].append(ticket)
        elif matched_count == 3:
            self.results["5등"].append(ticket)
    # 당첨복권 출력
    def display_ticket_with_matches(self, ticket):
        
        # 보너스 번호는 괄호로 표시
        display_ticket.append(f"+ 보너스번호: {'(' + str(ticket[-1]) + ')' if is_bonus_matched else str(ticket[-1])}")
        
        print("복권 번호:", " ".join(display_ticket))

# 실행 함수

lotto_system = LottoSystem(num_tickets=10000)
lotto_system.generate_lotto_tickets()
lotto_system.draw_winning_numbers()
lotto_system.check_winners()
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 77
#      75 lotto_system.generate_lotto_tickets()
#      76 lotto_system.draw_winning_numbers()
# ---> 77 lotto_system.check_winners()
#
# AttributeError: 'LottoSystem' object has no attribute 'check_winners'
